# %% [markdown]
# <img src="header.png" align="left"/>

# %% [markdown]
# # Exercise Analysis and quality control of data (10 points)
#
# The goal of this exercise is to get an overview of typical basic data analysis steps.
#
# - Datatypes and shapes of data
# - Prints of data
# - Missing values
# - Basic statistics
# - Outliers
# - Correlations between features
#
#
# Code and background taken from:
#
# - [https://towardsdatascience.com/ways-to-detect-and-remove-the-outliers-404d16608dba](https://towardsdatascience.com/ways-to-detect-and-remove-the-outliers-404d16608dba)
# - [https://towardsdatascience.com/5-ways-to-detect-outliers-that-every-data-scientist-should-know-python-code-70a54335a623](https://towardsdatascience.com/5-ways-to-detect-outliers-that-every-data-scientist-should-know-python-code-70a54335a623)
# - [https://github.com/Viveckh/HiPlotTutorial/blob/master/Hiplot-Tutorial.ipynb](https://github.com/Viveckh/HiPlotTutorial/blob/master/Hiplot-Tutorial.ipynb)

# %% [markdown]
# # Import of python modules

# %%
import pandas as pd
import numpy as np
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import hiplot as hip

from scipy import stats
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.cluster import DBSCAN

from keras.datasets import mnist
from keras.utils import to_categorical

# %%
#
# Turn of some warnings
#
from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)
simplefilter(action='ignore', category=Warning)

#
# Einstellen der Grösse von Diagrammen
#
plt.rcParams['figure.figsize'] = [16, 9]

# %% [markdown]
# # Datatypes and shapes of data
#
# https://numpy.org/devdocs/user/basics.types.html
#
# <img src="info.png" align="left"/>

# %%
# 
# Load some data
# 
names = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']
iris = pd.read_csv('data/iris/iris_mutilated.csv', names=names)

# %%
#
# Print shape of data
#
print(iris.shape)
# Out:
# (153, 5)

# %%
#
# Task: interpret those numbers in a short statement. (1 points)
# Hint: write your interpretation into your notebook in a MARKDOWN field.
# Meine Antwort

# %% [markdown]
# > Most data is represented in Matrix form. The shape of some data is basically the dimensions along each axix (width / height).

# %%
#
# Print datatypes
#
print(iris.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal-length  153 non-null    float64
#  1   sepal-width   153 non-null    float64
#  2   petal-length  152 non-null    float64
#  3   petal-width   151 non-null    float64
#  4   class         153 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.1+ KB
# None

# %% [markdown]
# # Print data

# %%
#
# Print head samples to see some data
#
print(iris.head(20))
# Out:
# sepal-length  sepal-width  petal-length  petal-width        class
# 0           5.1          3.5           1.0          0.2  Iris-setosa
# 1           4.9          3.0           NaN          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
#
# Task: describe what a NaN is (1 points)
#

# %% [markdown]
# > A NaN is basically a value that is not available, such as empty strings.

# %%
print(iris.tail())
# Out:
# sepal-length  sepal-width  petal-length  petal-width           class
# 148           6.7          3.0           5.2          2.3  Iris-virginica
# 149           6.3          2.5           5.0          1.9  Iris-virginica
# 150           6.5          3.0           5.2          2.0  Iris-virginica
# 151           6.2          3.4           5.4          2.3  Iris-virginica
# 152           5.9          3.0           5.1          1.8  Iris-virginica

# %% [markdown]
# # Missing data

# %%
#
# Print all rows with invalid data.
# Task: explain the function of this statement (2 points)
# 
iris[iris.isna().any(axis=1)]
# Out:
#      sepal-length  sepal-width  petal-length  petal-width           class
# 1             4.9          3.0           NaN          0.2     Iris-setosa
# 108           7.6          3.0           6.6          NaN  Iris-virginica
# 109           4.9          2.5           4.5          NaN  Iris-virginica

# %% [markdown]
# > The inside of the list iris[] basically shows all rows and marks the entries which have NaN values inside them. These values are then used as indencies for selecting all entries which are NaN

# %%
iris.isna().any(axis=1)
# Out:
# sepal-length    5.820915
# sepal-width     3.056863
# petal-length    3.728947
# petal-width     1.169536
# dtype: float64

# %%
#
# Print some statistical measures
#
iris.mean()
# Out:
# sepal-length    5.820915
# sepal-width     3.056863
# petal-length    3.728947
# petal-width     1.169536
# dtype: float64

# %%
#
# Replace missing values by mean value of feature
#
iris_non = iris.fillna(iris.mean())

# %%
iris_non[iris_non.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [sepal-length, sepal-width, petal-length, petal-width, class]
# Index: []

# %% [markdown]
# Filling the invalid data elements with the mean value may create disturbances. An alternative way to handle missing data would be to delete the complete row.

# %% [markdown]
# # Duplicates

# %%
#
# Test data for duplicates and remove them
# Task: explain this code (2 points)
#
iris_non[iris_non.duplicated(keep='first')]
# Out:
#      sepal-length  sepal-width  petal-length  petal-width           class
# 9             4.9          3.1           1.5          0.1     Iris-setosa
# 29            4.7          3.2           1.6          0.2     Iris-setosa
# 30            4.7          3.2           1.6          0.2     Iris-setosa
# 31            4.7          3.2           1.6          0.2     Iris-setosa
# 32            4.7          3.2           1.6          0.2     Iris-setosa
# 37            4.9          3.1           1.5          0.1     Iris-setosa
# 40            4.9          3.1           1.5          0.1     Iris-setosa
# 104           5.8          2.7           5.1          1.9  Iris-virginica
# 145           5.8          2.7           5.1          1.9  Iris-virginica

# %% [markdown]
# > The inside of iris_non[] querries all duplicated entries and marks them as True. These values are then used to querry all entries that are duplicates

# %% [markdown]
# # Simple statistics

# %%
#
# Distribution of class labels
#
print(iris_non.groupby('class').size())
# Out:
# class
# Iris-setosa        53
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
#
# Histogram of class distribution 
#
df = pd.DataFrame(iris_non,columns=['class'])
counts= df.groupby('class').size()
class_pos = np.arange(3)
plt.bar(class_pos, counts, align='center', alpha=0.4)
plt.xlabel(class_pos)
plt.ylabel('Ziffern')
plt.title('Samples pro Ziffer')
plt.show()

# %%
#
# Distribution of values in columns (features)
#
iris_non.describe()
# Out:
#        sepal-length  sepal-width  petal-length  petal-width
# count    153.000000   153.000000    153.000000   153.000000
# mean       5.820915     3.056863      3.728947     1.169536
# std        0.835137     0.429774      1.766264     0.763389
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.300000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # Outliers in the data

# %%
#
# Boxplots of features (outliers)
# Task: spot the outliers in the boxplots and describe the feature and the value range of the outliers (2 points)
#
iris_non.plot(kind='box', subplots=True, layout=(2,2), sharex=False, sharey=False)
plt.show()

# %% [markdown]
# The above diagrams show a few things
#
#     1. sepal-length: this box ranges froma minimum of aruond 4.5 to a max of around 8, the first Quantil begins at around 5.2 and ends with the median at aruond 5.8 which acts as starting point for the second Quantil ending at aruond 6.5.
#     2. sepal-width: here we have a some outliers at the maximum and and the minimum, the quantiles are much shorter
#     3. pedal-length: the interquartile range here is much higher, with the median being close to the 75%.
#     4. pedal-width similar to pedal-length, but in an overall smaller range

# %%
# Correlations between features

# %%
#
# Distribution of values per feature
#
iris_non.hist()
plt.show()

# %%
#
# Calculation of correlation facture between features
#
iris_non.corr()
# Out:
#               sepal-length  sepal-width  petal-length  petal-width
# sepal-length      1.000000    -0.116247      0.870525     0.817397
# sepal-width      -0.116247     1.000000     -0.426164    -0.354123
# petal-length      0.870525    -0.426164      1.000000     0.949181
# petal-width       0.817397    -0.354123      0.949181     1.000000

# %%
#
# Visual presentation of correlation between features
#
sns.heatmap(iris_non.corr(),annot=True,cmap='Blues_r')
# Out:
# <AxesSubplot:>

# %%
#
# Visualization as pair plot (scatter matrix)
#
scatter_matrix(iris_non)
plt.show()

# %%
#
# Advanced pair plot (seaborn library) now including the class of each data point
# Task: what do you think? Which of the three classes are separable (2 points)
#
sns.pairplot(iris_non,hue='class')

# %% [markdown]
# > It's very clear that iris-sectosa is an outlier and could interfere with the distribution. The other two classes should be the main concern

# %%
#
# Very advanced form of visualization of relations between features
#

# %%
iris_data = iris_non.to_dict('records')
iris_data[:2]
# Out:
# [{'sepal-length': 5.1,
#   'sepal-width': 3.5,
#   'petal-length': 1.0,
#   'petal-width': 0.2,
#   'class': 'Iris-setosa'},
#  {'sepal-length': 4.9,
#   'sepal-width': 3.0,
#   'petal-length': 3.728947368421053,
#   'petal-width': 0.2,
#   'class': 'Iris-setosa'}]

# %%
hip.Experiment.from_iterable(iris_data).display(force_full_width=True)
# Out:
# <div id="wrap_html_667c86"><!DOCTYPE html>
# <html>
#   <head>
#     <meta http-equiv="Content-Type" content="text/html;charset=utf-8"/>
#     <title>HiPlot</title>
#     <link rel="icon" href="static/icon.png" />
#   </head>
#   <body style="margin:0px">
#     <div id="hiplot_428b883a9bb042e981cc6f682d380b8f" style="background-color: white"><div style="text-align: center">Loading HiPlot...</div>
#       <noscript>
#         HiPlot needs JavaScript to run
#       </noscript>
#     </div>
#
#     <script  type="text/javascript" ></script>
#     <script type="text/javascript">
#     function _hiplot_setup() {
#       if (typeof hiplot == "undefined") {
#         console.info("waiting for HiPlot bundle to be loaded...");
#         setTimeout(_hiplot_setup, 1000);
#         return;
#       }
#       var options = {};
#       /*ON_LOAD_SCRIPT_INJECT*/
# const comm_id = "comm_d0e234";
# try {
#     console.log("Setting up communication channel with Jupyter: ", comm_id);
#     const comm = Jupyter.notebook.kernel.comm_manager.new_comm(comm_id, {'type': 'hello'});
#     var comm_message_id = 0;
#     function send_data_change(type, data) {
#         comm.send({
#             'type': type,
#             'message_id': comm_message_id,
#             'data': data,
#         });
#         comm_message_id += 1;
#     };
#     Object.assign(options, {"on_change": {
#         "selected_uids": send_data_change,
#         "brush_extents": send_data_change,
#     }});
# }
# catch(err) {
#     console.warn('Unable to create Javascript <-> Python communication channel' +
#         ' (are you in a Jupyter notebook? Jupyter labs is *not* supported!)');
# }
#
#         Object.assign(options, eval('(' + "{\"dataProviderName\": \"none\", \"experiment\": {\"datapoints\": [{\"uid\": \"0\", \"values\": {\"sepal-length\": 5.1, \"sepal-width\": 3.5, \"petal-length\": 1.0, \"petal-width\": 0.2, \"class\": \"Iris-setosa\"}, \"from_uid\": null}, {\"uid\": \"1\", \"values\": {\"sepal-length\": 4.9, \"sepal-width\": 3.0, \"petal-length\": 3.728947368421053, \"petal-width\": 0.2, \"class\": \"Iris-setosa\"}, \"from_uid\": null}, {\"uid\": \"2\", \"values\": {\"sepal-length\": 4.7, \"sepal-width\": 3.2, \"petal-length\": 1.3, \"petal-width\": 0.2, \"class\": \"Iris-setosa\"}, \"from_uid\": null}, {\"uid\": \"3\", \"values\": {\"sepal-length\": 4.6, \"sepal-width\": 3.1, \"petal-length\": 1.5, \"petal-width\": 0.2, \"class\": \"Iris-setosa\"}, \"from_uid\": null}, {\"uid\": \"4\", \"values\": {\"sepal-length\": 5.0, \"sepal-width\": 3.6, \"petal-length\": 1.4, \"petal-width\": 0.2, \"class\": \"Iris-setosa\"}, \"from_uid\": null}, {\"uid\": \"5\", \"values\": {\"sepal-length\": 5.4, \"sepal-width\": 3.9, \"petal-length\": 1.7, \"petal-width\": 0.4, \"class\": \"Iris-setosa\"}, \"from_uid\": null}, {\"uid\": \"6\", \"values\": {\"sepal-length\": 4.6, \"sepal-width\": 3.4, \"petal-length\": 1.4, \"petal-width\": 0.3, \"class\": \"Iris-setosa\"}, \"from_uid\": null}, {\"uid\": \"7\", \"values\": {\"sepal-length\": 5.0, \"sepal-width\": 3.4, \"petal-length\": 1.5, \"petal-width\": 0.2, \"class\": \"Iris-setosa\"}, \"from_uid\": null}, {\"uid\": \"8\", \"values\": {\"sepal-length\": 4.4, \"sepal-width\": 2.9, \"petal-length\": 1.4, \"petal-width\": 0.2, \"class\": \"Iris-setosa\"}, \"from_uid\": null}, {\"uid\": \"9\", \"values\": {\"sepal-length\": 4.9, \"sepal-width\": 3.1, \"petal-length\": 1.5, \"petal-width\": 0.1, \"class\": \"Iris-setosa\"}, \"from_uid\": null}, {\"uid\": \"10\", \"values\": {\"sepal-length\": 5.4, \"sepal-width\": 3.7, \"petal-length\": 1.5, \"petal-width\": 0.2, \"class\": \"Iris-setosa\"}, \"from_uid\": null}, {\"uid\": \"11\", \"values\": {\"sepal-length\": 4.8, \"sepal-width\": 3.4, \"petal-length\": 1.6, \"petal-width\": 0.2, \"class\": \"Iris-setosa\"}, \"from_uid\": null}, {\"uid\": \"12\", \"values\": {\"sepal-length\": 4.8, \"sepal-width\": 3.0, \"petal-length\": 1.4, \"petal-width\": 0.1, \"class\": \"Iris-setosa\"}, \"from_uid\": null}, {\"uid\": \"13\", \"values\": {\"sepal-length\": 4.3, \"sepal-width\": 3.0, \"petal-length\": 1.1, \"petal-width\": 0.1, \"class\": \"Iris-setosa\"}, \"from_uid\": null}, {\"uid\": \"14\", \"values\": {\"sepal-length\": 5.8, \"sepal-width\": 4.0, \"petal-length\": 1.2, \"petal-width\": 0.2, \"class\": \"Iris-setosa\"}, \"from_uid\": null}, {\"uid\": \"15\", \"values\": {\"sepal-length\": 5.7, \"sepal-width\": 4.4, \"petal-length\": 1.5, \"petal-width\": 0.4, \"class\": \"Iris-setosa\"}, \"from_uid\": null}, {\"uid\": \"16\", \"values\": {\"sepal-length\": 5.4, \"sepal-width\": 3.9, \"petal-length\": 1.3, \"petal-width\": 0.4, \"class\": \"Iris-setosa\"}, \"from_uid\": null}, {\"uid\": \"17\", \"values\": {\"sepal-length\": 5.1, \"sepal-width\": 3.5, \"petal-length\": 1.4, \"petal-width\": 0.3, \"class\": \"Iris-setosa\"}, \"from_uid\": null}, {\"uid\": \"18\", \"values\": {\"sepal-length\": 5.7, \"sepal-width\": 3.8, \"petal-length\": 1.7, \"petal-width\": 0.3, \"class\": \"Iris-setosa\"}, \"from_uid\": null}, {\"uid\": \"19\", \"values\": {\"sepal-length\": 5.1, \"sepal-width\": 3.8, \"petal-length\": 1.5, \"petal-width\": 0.3, \"class\": \"Iris-setosa\"}, \"from_uid\": null}, {\"uid\": \"20\", \"values\": {\"sepal-length\": 5.4, \"sepal-width\": 3.4, \"petal-length\": 1.7, \"petal-width\": 0.2, \"class\": \"Iris-setosa\"}, \"from_uid\": null}, {\"uid\": \"21\", \"values\": {\"sepal-length\": 5.1, \"sepal-width\": 3.7, \"petal-length\": 1.5, \"petal-width\": 0.4, \"class\": \"Iris-setosa\"}, \"from_uid\": null}, {\"uid\": \"22\", \"values\": {\"sepal-length\": 4.6, \"sepal-width\": 3.6, \"petal-length\": 1.0, \"petal-width\": 0.2, \"c ...
